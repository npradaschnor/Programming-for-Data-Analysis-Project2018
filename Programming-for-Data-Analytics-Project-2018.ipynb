# %% [markdown]
# <img src="https://image.ibb.co/kt1M0V/GMIT-LOGO.png" alt="GMIT-LOGO" border="0" width="50%">
#
#
# # Higher Diploma in Science in Computing (Data Analytics)
#
#
# ## Programming for Data Analytics - Project 2018
#
# ### Noa Pereira Prada Schnor

# %% [markdown]
# ## About the project
#
# A data set must be created  by simulating a real-world phenomenon chosen by the student. As I could pick any phenomenon, I've chosen one that is of my interest and related to my professional background: obesity. After I chose the phenomenom, I should model and synthesise such data using Python. It was suggested to use the numpy.random package for this purpose.
#
# This project includes:
#
# • Real-world phenomenon that can be measured and for which could collect at least one-hundred data points across at least four different variables.
#
# • Investigation of the types of variables involved, their likely distributions, and their relationships with each other.
#
# • Simulation of a data set as closely matching their properties as possible.
#
# • Description of the research and implemention of the simulation in a Jupyter notebook – the data set itself can simply be displayed in an output cell within the notebook.

# %% [markdown]
# #### Chosen problem: OBESITY
# #### Population: female, adults
# #### Country: Ireland
#
# [Obesity] <img src="https://i.ibb.co/M2ZW7bw/scale-2396062-1920.jpg" alt="scale-2396062-1920" border="0"  width="25%">

# %% [markdown]
# In Ireland 60% of adults are overweight (excess weight or obese) [1]. Besides, the prevalence of excess weight/obesity in adults from 18 to 64 years in Ireland has increased since 1990. Therefore, it still is a major public health problem in Ireland [2].
# It's estimated that an adult woman needs 1600 to 2400 calories per day and it depends on a number of factors, such as age, height, weight and level of physical activity. So, the low end of the calories needed per day is for sedentary women and the higher end of the range is for the active women [3].
# It is well known that to maintain a healthy weight the amount of calories consumed must be in balance with the amount of calories burnt. Therefore, the amount of calories consumed must be greater than the calories burnt to result in  a gain weight [4].
# It is no wonder that  the average daily consumption of calories in Ireland is 2307 calories. The world  average daily consumption of calories is 1398. So, come as no surprise that the average daily energy consumption of calories in Ireland it is one of the biggest in the world [5].

# %% [markdown]
# The database created includes only overweight and obese adult women in Ireland.
#
# #### The variables chosen are:
#
# 1.  Age
# 2. BMI (Body Mass Index)
# 3. Energy intake per day
# 4. WHR (Waist:Hip Ratio)

# %% [markdown]
# #### Age:
# The average age of adults in Ireland is 37.4 years [6]. Surveys in Ireland usually include adults from 18 to 64 years old.
#
# #### BMI:
# The BMI (Quetelet Index) indicates the nutritional status in adults and it's a measure defined as the weight (in kilograms) divided by the square of height (in metres) [9].The World Health Organisation (WHO) BMI cut-off points were used to estimate the nutritional status. As there is no maximum BMI for obese women, it was considered 45 kg/m2 as the BMI of morbidly obese person is equal or greater than 40 kg/m2.
#
#
#
# [BMI formula] <img src="https://image.ibb.co/io1FqL/BMI-Formula-1.jpg" alt="BMI-Formula-1" border="0" width="30%">
#
#
#
# [BMI nutritional status] <img src="https://image.ibb.co/fggtCA/BMI-chart.png" alt="BMI-chart" border="0" width="50%">
#
#
# The National Adult Nutrition Survey in 2011 with a 1500 adults (740 men and 760 women) showed that among 18 to 64 years old women a total of 21% were obese and 31% were overweight [2]. Two lists of random BMI values were created based on NANS 2011 proportion of number of women overweight and obese.
#
#
# #### Energy intake per day:
# The average consumption of calories in Ireland is 2307 [5].
#
# #### WHR (Waist:Hip Ratio):
# The adult Irish population has an average value of 0.84 (std 0.08) of WHR [2]. As body fat distribution is an important indicator of disease risk, the WHR is used to predict the risk of a cardiovascular disease (CVD). It was showed an increased WHR in women, which indicated a high risk of CVD [2]. The WHO cut off for WHR for increased risk of CVD is 0.85 (as showed in the following table).
#
#
# [WHR WHO cut off] <img src="https://i.ibb.co/tBvwyD1/whrwhocutoff.png" alt="whrwhocutoff" border="0" width="90%">

# %% [markdown]
# #### Number of the sample of the project: 520 women
#
# Based on NANS 2011 Survey with a sample of 1500 individuals (760 women), where 48% of them had healthy weight, 31% were overweight and 21% were obese.
# I've decided to get just the data from women with any degree of excess weight. Therefore, among 1000 women (48% healthy weight, 31% overweight, 21% obese), 480 would have a healthy weight and 520 would have a degree of excess of weight (310 overweight and 210 obese).
#
# <center><img src="https://i.ibb.co/HtQGXHD/samplesizeproject.png" alt="samplesizeproject" border="0"></center>

# %%
#Import libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()

# %% [markdown]
# ### Age

# %%
# Generate age between 18 and 64 years old

age = np.random.randint(18, 64, 520)

age
# Out:
# array([22, 25, 63, 28, 30, 24, 39, 29, 36, 42, 22, 33, 50, 50, 30, 58, 27,
#        40, 36, 35, 44, 22, 25, 54, 39, 19, 18, 20, 59, 18, 43, 29, 47, 60,
#        28, 23, 21, 28, 46, 41, 59, 46, 55, 50, 54, 44, 51, 27, 49, 51, 33,
#        51, 61, 34, 21, 57, 35, 58, 62, 36, 31, 28, 43, 60, 34, 19, 21, 58,
#        44, 46, 60, 51, 26, 23, 18, 18, 54, 51, 59, 26, 31, 34, 18, 43, 58,
#        58, 22, 18, 20, 51, 19, 19, 23, 53, 37, 40, 35, 58, 52, 47, 32, 20,
#        45, 27, 36, 63, 57, 30, 60, 59, 26, 20, 29, 27, 55, 51, 36, 47, 45,
#        62, 50, 62, 18, 33, 26, 26, 33, 43, 53, 19, 45, 39, 39, 41, 21, 35,
#        21, 56, 29, 59, 60, 30, 31, 30, 54, 25, 60, 63, 58, 28, 57, 34, 33,
#        26, 45, 37, 44, 19, 22, 48, 36, 51, 21, 60, 44, 27, 36, 45, 63, 33,
#        55, 47, 19, 58, 34, 46, 37, 47, 24, 19, 60, 37, 63, 59, 53, 62, 63,
#        34, 51, 19, 46, 22, 25, 32, 22, 63, 43, 23, 46, 55, 44, 33, 46, 52,
#        59, 21, 28, 40, 35, 21, 41, 18, 40, 56, 45, 58, 52, 52, 40, 29, 42,
#        60, 55, 36, 33, 41, 40, 22, 54, 57, 55, 19, 51, 50, 51, 23, 19, 38,
#        20, 46, 33, 23, 27, 46, 18, 18, 25, 58, 23, 20, 52, 57, 26, 18, 58,
#        49, 45, 58, 55, 45, 58, 59, 50, 61, 62, 21, 48, 44, 48, 48, 24, 20,
#        50, 38, 32, 59, 21, 22, 29, 58, 58, 56, 50, 38, 22, 31, 33, 53, 59,
#        39, 25, 27, 20, 25, 51, 47, 49, 24, 32, 19, 36, 24, 59, 41, 26, 26,
#        35, 58, 31, 62, 63, 39, 35, 24, 44, 37, 37, 24, 42, 60, 53, 55, 37,
#        59, 50, 52, 39, 51, 49, 47, 47, 28, 21, 25, 33, 37, 44, 39, 44, 27,
#        31, 28, 43, 40, 27, 52, 37, 55, 31, 20, 51, 59, 63, 40, 58, 43, 20,
#        46, 51, 26, 47, 39, 47, 44, 19, 25, 57, 58, 22, 51, 39, 28, 47, 36,
#        63, 33, 43, 28, 19, 40, 56, 39, 56, 35, 30, 54, 60, 52, 34, 54, 26,
#        25, 61, 19, 49, 49, 56, 44, 49, 50, 32, 34, 27, 46, 21, 57, 62, 22,
#        27, 24, 22, 50, 63, 53, 45, 19, 28, 38, 29, 59, 44, 57, 63, 62, 31,
#        43, 46, 57, 61, 55, 21, 48, 38, 45, 51, 49, 43, 41, 62, 19, 32, 62,
#        56, 31, 51, 21, 49, 47, 31, 62, 26, 47, 36, 48, 54, 45, 61, 32, 51,
#        29, 46, 43, 32, 37, 44, 18, 61, 54, 19, 20, 30, 42, 63, 24, 20, 21,
#        58, 51, 30, 31, 21, 56, 42, 37, 35, 24, 33, 45, 62, 28, 36, 35, 61,
#        52, 43, 57, 53, 41, 57, 26, 48, 59, 54, 54, 53, 63, 31, 55, 46, 58,
#        28, 57, 30, 35, 36, 18, 42, 26, 58, 24])

# %%
# Average age of the sample

# Higher than the national average of 37.4 years old

np.mean(age)
# Out:
# 40.5

# %%
# Median 

np.median(age)
# Out:
# 41.0

# %%
#Plot the age

# Histogram

# 3 main peaks: 58, 51 and 19

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(age, bins=100)
plt.xlabel('Age in years')
plt.show()

# %%
#Boxplot


# Red triangle is the mean and the line inside the box is the median. Normal distribution - mean similar to median.

plt.boxplot(age, showmeans=True)
plt.show()

# %% [markdown]
# ### Body Mass Index (BMI)

# %%
# Overweight - BMI greater or equal 25kg/m2 and less than 30 kg/m2

#Min and max weight to be classified as overweight

min_bmi_overweight = 25
max_bmi_overweight = 29.99

# %%
bmi_overweight = np.random.uniform(25,29.99, 310)

bmi_overweight
# Out:
# array([ 26.43783886,  25.09529571,  28.57121844,  29.43446466,
#         28.22856786,  27.67158325,  28.2598683 ,  29.58313773,
#         28.42452226,  28.49893769,  26.70126322,  29.17288041,
#         28.85035151,  25.82967008,  27.42188193,  28.43797589,
#         29.89679691,  27.74839249,  26.73508875,  27.02630124,
#         28.58337055,  28.31052182,  25.00832353,  28.13121474,
#         29.45248175,  26.92879644,  27.86164201,  26.60889114,
#         26.08382722,  26.15351566,  28.02559514,  27.86327797,
#         25.67929291,  27.10592546,  25.64906605,  27.67977226,
#         27.87048034,  29.46392758,  26.03221108,  25.69426691,
#         25.45797815,  29.79151411,  25.08676731,  28.68538772,
#         25.60032861,  27.32130526,  28.42536122,  25.28648501,
#         25.92901865,  28.97259242,  27.61330106,  29.43448636,
#         29.15139708,  26.62488224,  27.01565951,  25.25832913,
#         29.95430338,  25.1632253 ,  28.62021096,  26.06984187,
#         28.26346532,  27.04330059,  27.10231013,  27.37533646,
#         27.13235162,  25.58364165,  28.09531954,  25.36295773,
#         27.34056519,  25.79877663,  25.23396606,  29.52285142,
#         26.88571853,  28.23193505,  29.24648993,  29.41846439,
#         27.79145521,  29.57708813,  29.54748417,  27.93423804,
#         27.53433672,  25.04825638,  28.43889809,  28.32153975,
#         28.05795114,  27.07806431,  29.73224161,  27.77774879,
#         28.60242636,  29.7315272 ,  27.75163583,  27.83023863,
#         26.76220902,  29.93777261,  25.26754896,  25.82478707,
#         28.24732582,  28.37890645,  28.57823191,  27.27842354,
#         27.65109574,  29.45556193,  26.26569447,  28.28082057,
#         27.87469566,  28.27675123,  27.06335341,  26.31800389,
#         26.20416492,  29.30897143,  28.32050383,  27.92895277,
#         26.61276438,  26.6681872 ])

# %%
# Average BMI of overweight women

np.mean (bmi_overweight)
# Out:
# 27.487760581010686

# %%
np.median(bmi_overweight)
# Out:
# 27.548182480181204

# %%
#Plot overweight sample

# Histogram

# Peaks at values between 25, 28 and 27

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(bmi_overweight)
plt.show()

# %%
#Box plot

#Normal distribution - mean similar to median

plt.boxplot(bmi_overweight, showmeans=True)
plt.show()

# %%
# obesity - BMI greater or equal 30 kg/m2 (there is no max BMI, but it was considered 45 kg/m2)

#Min and 'max' BMI to be classified as obese

min_bmi_obese = 30
max_bmi_obese = 45

# %%
bmi_obese = np.random.uniform(30,45, 210)

bmi_obese
# Out:
# array([ 33.04958643,  33.80282459,  32.56762919,  39.41691707,
#         41.09555695,  36.16564343,  33.98097337,  32.87111152,
#         44.48017499,  41.53648525,  37.93269775,  36.51984351,
#         41.16921336,  33.58214564,  43.7521192 ,  32.18199803,
#         30.80159221,  39.71010154,  33.70701401,  39.92190737,
#         40.61600707,  30.36837561,  42.91293115,  40.57479457,
#         33.72361753,  32.4154806 ,  42.38638605,  38.30582835,
#         33.04013163,  37.00720715,  35.0756037 ,  30.3712096 ,
#         43.42730973,  34.80318653,  40.76681829,  38.89561901,
#         39.37004062,  41.98951992,  34.33907329,  35.74794491,
#         40.00878592,  30.04221756,  31.26327719,  31.43528341,
#         30.82577422,  39.65157595,  30.60475633,  38.64606229,
#         41.1957932 ,  41.16495899,  34.67541962,  44.78226661,
#         42.11228301,  36.3477984 ,  36.43423204,  43.83425021,
#         39.71894792,  34.89542619,  35.38388195,  35.94726301,
#         36.69188483,  30.84922891,  43.25524031,  35.75557567,
#         31.54382687,  40.03525769,  43.63525706,  35.66421792,
#         39.11792101,  40.97954133,  32.13949324,  33.746724  ,
#         43.20634184,  38.11050315,  37.14396702,  42.71240162,
#         39.22032813,  39.1421265 ,  41.6824686 ,  38.50777477,
#         43.16063322,  38.13368937,  33.76966401,  36.85702109,
#         41.53530539,  39.24545026,  39.63152575,  33.4683712 ,
#         42.22153133,  44.34112225,  42.3091152 ,  41.55226218,
#         41.10314448,  38.46510359,  35.49668469,  33.3060114 ,
#         31.75502094,  37.14307453,  44.49241104,  31.17116907,
#         33.53995839,  42.47740431,  35.63531067,  33.97707488,
#         38.90023373,  42.51755177,  30.73482415,  35.22479722,
#         37.79780854,  38.26383698,  32.99715134,  33.76962559,
#         30.8000845 ,  33.92457783,  42.01788091,  32.03827022,
#         36.8708477 ,  32.25491174,  44.42536363,  44.34958972,
#         36.31319912,  42.3840697 ,  36.98198436,  34.45315574,
#         33.40361714,  39.83695376,  37.59604296,  40.92361832,
#         42.56355804,  37.21306868,  36.10837735,  36.53827711,
#         38.04832529,  42.74486655,  30.26378455,  33.94035955,
#         43.533276  ,  37.42643464,  33.04438939,  34.68946401,
#         33.38183118,  44.95251532,  43.17516525,  39.56348273,
#         42.63220848,  42.44099808,  39.10242603,  43.6381201 ,
#         36.28508859,  40.30639006,  39.18812878,  37.17624661,
#         41.72826937,  34.41078477,  37.31835221,  32.74129681,
#         31.4583341 ,  42.62186575,  43.47930517,  44.20212461,
#         40.43140938,  43.94316431,  39.44830286,  38.79433936,
#         40.05715972,  35.55310201,  38.6471223 ,  35.27102081,
#         36.53503248,  43.46574497,  31.75111411,  39.95134285,
#         35.35655818,  30.95940391,  43.28865603,  36.83709577,
#         39.1290153 ,  38.71829411,  43.82034462,  42.16506931,
#         37.06081332,  32.58463911,  34.80070285,  39.13532638,
#         40.62970277,  38.29085486,  32.72262094,  36.4935761 ,
#         34.78461198,  32.2988501 ,  32.26266047,  31.15082187,
#         41.89699837,  43.70574563,  44.145808  ,  30.38213188,
#         36.89412061,  44.93743201,  32.62842604,  35.3377484 ,
#         39.50145418,  37.21525905,  30.66346238,  30.05490421,
#         36.61934714,  32.84312646,  42.87530267,  32.17546727,
#         41.61044477,  43.42986734])

# %%
# Average and median BMI of obese women

np.mean (bmi_obese)
# Out:
# 37.615398313540013

# %%
np.median (bmi_obese)
# Out:
# 37.511238803281159

# %%
#Plot overweight sample

# Histogram

# Peaks at values between 36 and 37, between 39 and 40 and between 42 and 43.

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(bmi_obese)
plt.show()

# %%
# Box plot

# Normal distribution - mean similar to median

plt.boxplot(bmi_obese, showmeans=True)
plt.show()

# %%
#Create one single array containing all the sample BMI (overweight and obese)

bmi = np.concatenate ((bmi_overweight, bmi_obese), axis=None)
bmi
# Out:
# array([ 26.43783886,  25.09529571,  28.57121844,  29.43446466,
#         28.22856786,  27.67158325,  28.2598683 ,  29.58313773,
#         28.42452226,  28.49893769,  26.70126322,  29.17288041,
#         28.85035151,  25.82967008,  27.42188193,  28.43797589,
#         29.89679691,  27.74839249,  26.73508875,  27.02630124,
#         28.58337055,  28.31052182,  25.00832353,  28.13121474,
#         29.45248175,  26.92879644,  27.86164201,  26.60889114,
#         26.08382722,  26.15351566,  28.02559514,  27.86327797,
#         25.67929291,  27.10592546,  25.64906605,  27.67977226,
#         27.87048034,  29.46392758,  26.03221108,  25.69426691,
#         25.45797815,  29.79151411,  25.08676731,  28.68538772,
#         37.59604296,  40.92361832,  42.56355804,  37.21306868,
#         36.10837735,  36.53827711,  38.04832529,  42.74486655,
#         30.26378455,  33.94035955,  43.533276  ,  37.42643464,
#         33.04438939,  34.68946401,  33.38183118,  44.95251532,
#         43.17516525,  39.56348273,  42.63220848,  42.44099808,
#         39.10242603,  43.6381201 ,  36.28508859,  40.30639006,
#         39.18812878,  37.17624661,  41.72826937,  34.41078477,
#         37.31835221,  32.74129681,  31.4583341 ,  42.62186575,
#         43.47930517,  44.20212461,  40.43140938,  43.94316431,
#         39.44830286,  38.79433936,  40.05715972,  35.55310201,
#         38.6471223 ,  35.27102081,  36.53503248,  43.46574497,
#         31.75111411,  39.95134285,  35.35655818,  30.95940391,
#         43.28865603,  36.83709577,  39.1290153 ,  38.71829411,
#         43.82034462,  42.16506931,  37.06081332,  32.58463911,
#         34.80070285,  39.13532638,  40.62970277,  38.29085486,
#         32.72262094,  36.4935761 ,  34.78461198,  32.2988501 ,
#         32.26266047,  31.15082187,  41.89699837,  43.70574563,
#         44.145808  ,  30.38213188,  36.89412061,  44.93743201,
#         32.62842604,  35.3377484 ,  39.50145418,  37.21525905,
#         30.66346238,  30.05490421,  36.61934714,  32.84312646,
#         42.87530267,  32.17546727,  41.61044477,  43.42986734])

# %%
# Average BMI of the sample

np.mean(bmi)
# Out:
# 31.577768126839832

# %%
#Median BMI 

np.median(bmi)
# Out:
# 29.201341342735084

# %%
from __future__ import division, print_function
import numpy as np

__author__ = "Marcos Duarte, https://github.com/demotu/BMC"
__version__ = "1.0.5"
__license__ = "MIT"


def detect_peaks(x, mph=None, mpd=1, threshold=0, edge='rising',
                 kpsh=False, valley=False, show=False, ax=None):
    
    x = np.atleast_1d(x).astype('float64')
    
    if x.size < 3:
        return np.array([], dtype=int)
    if valley:
        x = -x
        if mph is not None:
            mph = -mph
    # find indices of all peaks
    dx = x[1:] - x[:-1]
    # handle NaN's
    indnan = np.where(np.isnan(x))[0]
    if indnan.size:
        x[indnan] = np.inf
        dx[np.where(np.isnan(dx))[0]] = np.inf
    ine, ire, ife = np.array([[], [], []], dtype=int)
    if not edge:
        ine = np.where((np.hstack((dx, 0)) < 0) & (np.hstack((0, dx)) > 0))[0]
    else:
        if edge.lower() in ['rising', 'both']:
            ire = np.where((np.hstack((dx, 0)) <= 0) & (np.hstack((0, dx)) > 0))[0]
        if edge.lower() in ['falling', 'both']:
            ife = np.where((np.hstack((dx, 0)) < 0) & (np.hstack((0, dx)) >= 0))[0]
    ind = np.unique(np.hstack((ine, ire, ife)))
    # handle NaN's
    if ind.size and indnan.size:
        # NaN's and values close to NaN's cannot be peaks
        ind = ind[np.in1d(ind, np.unique(np.hstack((indnan, indnan-1, indnan+1))), invert=True)]
    # first and last values of x cannot be peaks
    if ind.size and ind[0] == 0:
        ind = ind[1:]
    if ind.size and ind[-1] == x.size-1:
        ind = ind[:-1]
    # remove peaks < minimum peak height
    if ind.size and mph is not None:
        ind = ind[x[ind] >= mph]
    # remove peaks - neighbors < threshold
    if ind.size and threshold > 0:
        dx = np.min(np.vstack([x[ind]-x[ind-1], x[ind]-x[ind+1]]), axis=0)
        ind = np.delete(ind, np.where(dx < threshold)[0])
    # detect small peaks closer than minimum peak distance
    if ind.size and mpd > 1:
        ind = ind[np.argsort(x[ind])][::-1]  # sort ind by peak height
        idel = np.zeros(ind.size, dtype=bool)
        for i in range(ind.size):
            if not idel[i]:
                # keep peaks with the same height if kpsh is True
                idel = idel | (ind >= ind[i] - mpd) & (ind <= ind[i] + mpd) \
                    & (x[ind[i]] > x[ind] if kpsh else True)
                idel[i] = 0  # Keep current peak
        # remove the small peaks and sort back the indices by their occurrence
        ind = np.sort(ind[~idel])

    if show:
        if indnan.size:
            x[indnan] = np.nan
        if valley:
            x = -x
            if mph is not None:
                mph = -mph
        _plot(x, mph, mpd, threshold, edge, valley, ax, ind)

    return ind


def _plot(x, mph, mpd, threshold, edge, valley, ax, ind):
    """Plot results of the detect_peaks function, see its help."""
    try:
        import matplotlib.pyplot as plt
    except ImportError:
        print('matplotlib is not available.')
    else:
        if ax is None:
            _, ax = plt.subplots(1, 1, figsize=(8, 4))

        ax.plot(x, 'b', lw=1)
        if ind.size:
            label = 'valley' if valley else 'peak'
            label = label + 's' if ind.size > 1 else label
            ax.plot(ind, x[ind], '+', mfc=None, mec='r', mew=2, ms=8,
                    label='%d %s' % (ind.size, label))
            ax.legend(loc='best', framealpha=.5, numpoints=1)
        ax.set_xlim(-.02*x.size, x.size*1.02-1)
        ymin, ymax = x[np.isfinite(x)].min(), x[np.isfinite(x)].max()
        yrange = ymax - ymin if ymax > ymin else 1
        ax.set_ylim(ymin - 0.1*yrange, ymax + 0.1*yrange)
        ax.set_xlabel('Data #', fontsize=14)
        ax.set_ylabel('Amplitude', fontsize=14)
        mode = 'Valley detection' if valley else 'Peak detection'
        ax.set_title("%s (mph=%s, mpd=%d, threshold=%s, edge='%s')"
                     % (mode, str(mph), mpd, str(threshold), edge))
        # plt.grid()
        plt.show()
        
ind = detect_peaks(bmi, mph = 25, mpd = 25, threshold = 4, edge = 'rising', show=True)
ind
# Out:
# array([ 41, 324, 365, 408, 457, 507], dtype=int64)

# %%
# Check the performance of [detect_peaks from Marcos Duarte](http://nbviewer.jupyter.org/github/demotu/BMC/blob/master/notebooks/DetectPeaks.ipynb)

ind = detect_peaks(bmi)
print('Data with %d points and %d peaks\n' %(bmi.size, ind.size))
print('Performance (without the minimum peak distance parameter):')
print('detect_peaks(bmi)')
# %timeit detect_peaks(bmi)
print('\nPerformance (using the minimum peak distance parameter):')
print('detect_peaks(bmi, mpd=10)')
# %timeit detect_peaks(bmi, mpd=10)
# Out:
# Data with 520 points and 163 peaks
#
# Performance (without the minimum peak distance parameter):
# detect_peaks(bmi)
# 92.2 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
#
# Performance (using the minimum peak distance parameter):
# detect_peaks(bmi, mpd=10)
# 534 µs ± 19.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#
#         1736.72305111,  2118.66918319,  1739.62221561,  3232.82865976,
#         2713.41369855,  2688.08496177,  1741.69838104,  2245.8472852 ,
#         2586.79538135,  2702.83518947,  2632.97688122,  2368.02002195,
#         3208.49245942,  1891.21320662,  1542.06822725,  2484.96587915,
#         2889.13229132,  2047.12362926,  1636.0033302 ,  2239.0666874 ,
#         1014.27837957,  2494.97514368,  2343.90273133,  1635.93054878])

# %%
#Maximum and minimun daily energy intake

np.amax(energy_intake)
# Out:
# 3748.3581960446772

# %%
np.amin(energy_intake)
# Out:
# 953.46239741579666

# %%
# Energy intake from is 953.46 to 3748.35 kcal per day. Probably there is underreporting of energy consumed by individual from the sample or some of them might be on a diet. Further investigation is needed.

# %%
#Median and average energy intake per day

np.median(energy_intake)
# Out:
# 2270.9702741889214

# %%
np.mean(energy_intake)
# Out:
# 2268.539385574582

# %%
# Plot - Daily Energy Intake

# Histogram

#Main peaks: between 2200 and 2300, 1900, and 2700

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(energy_intake, bins=50)
plt.xlabel('Daily energy intake (kcal)')
plt.show()

# %%
#Box plot

# Normal distribution - mean similar to median

plt.boxplot (energy_intake, showfliers=True, showmeans=True)
plt.show()

# %%
#Check the peaks of Energy Intake

ind_energy = detect_peaks(energy_intake, mpd = 50, threshold = 4, edge = 'rising', show=True)
ind_energy
# Out:
# array([ 13,  83, 167, 266, 364, 464, 517], dtype=int64)

# %%
# Check the performance of [detect_peaks from Marcos Duarte](http://nbviewer.jupyter.org/github/demotu/BMC/blob/master/notebooks/DetectPeaks.ipynb)

ind = detect_peaks(energy_intake)
print('Data with %d points and %d peaks\n' %(energy_intake.size, ind.size))
print('Performance (without the minimum peak distance parameter):')
print('detect_peaks(energy_intake)')
# %timeit detect_peaks(energy_intake)
print('\nPerformance (using the minimum peak distance parameter):')
print('detect_peaks(energy_intake, mpd=10)')
# %timeit detect_peaks(energy_intake, mpd=10)
# Out:
# Data with 520 points and 177 peaks
#
# Performance (without the minimum peak distance parameter):
# detect_peaks(energy_intake)
# 97.5 µs ± 8.07 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
#
# Performance (using the minimum peak distance parameter):
# detect_peaks(energy_intake, mpd=10)
# 548 µs ± 21.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Waist - Hip Ratio (WHR)

# %%
# Generate Waist:Hip Ratio - WHR numbers

whr = np.random.normal(0.84, 0.08, 520)

whr
# Out:
# array([ 0.70793748,  0.72907109,  0.87069276,  0.92504114,  0.79776272,
#         0.83990454,  0.86676068,  0.67794289,  1.00474468,  0.81585055,
#         0.85796681,  0.95067898,  0.99286776,  0.75044132,  0.81440897,
#         0.75350649,  0.87906309,  0.92705377,  0.66782948,  0.82635331,
#         0.81047435,  0.85056296,  0.77077728,  0.74236642,  0.86064012,
#         0.9573723 ,  0.88398228,  0.91545596,  0.88779707,  0.8948222 ,
#         0.82298419,  1.05216354,  0.78337495,  0.87333124,  0.8712211 ,
#         0.67620425,  0.88658629,  0.76088048,  0.88448044,  0.77931115,
#         0.90186452,  0.63730562,  0.84465738,  0.92525685,  0.86435955,
#         0.91524246,  0.82823783,  1.00938924,  0.79160695,  0.97731933,
#         1.06441495,  0.94192926,  0.83071579,  0.89485881,  0.77227803,
#         0.87507023,  0.90119186,  0.87610641,  0.9025509 ,  0.92146582,
#         0.84907361,  0.75662901,  0.77076339,  0.73337403,  0.76865448,
#         0.82981968,  0.77658779,  0.82403643,  0.94547571,  0.98409531,
#         0.76117468,  0.84007809,  0.82485244,  0.77698483,  0.74172876,
#         0.92712855,  0.85598203,  0.82469157,  0.86358105,  0.92419566,
#         0.80171158,  0.7981184 ,  0.87029136,  0.91838854,  0.93562551,
#         0.93289992,  0.92104823,  0.87855263,  0.75485038,  0.8938695 ,
#         0.78666812,  0.96300952,  0.89701335,  1.03026578,  0.8623689 ,
#         0.90779754,  0.90178348,  0.74629671,  0.86922238,  0.7371036 ,
#         0.88395858,  0.90687323,  0.99510277,  0.88147654,  0.78541385,
#         0.84539472,  0.86317024,  0.81739826,  0.74672482,  0.85636044,
#         0.96259735,  0.71203674,  0.87439694,  0.9660674 ,  0.89999119,
#         0.92677506,  0.7186609 ,  0.80860762,  1.00415019,  0.76574878,
#         0.87286828,  0.98788006,  0.77446353,  0.98515097,  0.92468881])

# %%
# Max and min WHR value

np.amax(whr)
# Out:
# 1.0644149457030891

# %%
np.amin(whr)
# Out:
# 0.57966079917211966

# %%
#WHR values from 0.58 to 1.06. Individual with WHR of 0.58 might present a body shape of 'pear' (hips bigger than waist).

########### COLOCAR FOTO APLE VS PEAR.JPG

# %%
# Plot - WHR

#Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(whr, bins=50)
plt.xlabel('Waist-Hip Ratio')
plt.show()

# %%
#Boxplot

#Normal distribution - mean similar to median

plt.boxplot (whr, showmeans=True)
plt.show ()

# %% [markdown]
# ### Dataframe containing all data generated

# %%
#Create dataframe with all the data randomly generated

df=pd.DataFrame(data={'Age': age, 'BMI': bmi, 'WHR': whr, 'Daily Energy Intake': energy_intake})

df
# Out:
#      Age        BMI  Daily Energy Intake       WHR
# 0     22  26.437839          1728.998770  0.707937
# 1     25  25.095296           979.258318  0.729071
# 2     63  28.571218          2293.341875  0.870693
# 3     28  29.434465          2609.896953  0.925041
# 4     30  28.228568          2825.043539  0.797763
# 5     24  27.671583          2405.093351  0.839905
# 6     39  28.259868          2893.725866  0.866761
# 7     29  29.583138          1951.984964  0.677943
# 8     36  28.424522          2433.843256  1.004745
# 9     42  28.498938          2163.905477  0.815851
# 10    22  26.701263          2485.051496  0.857967
# 11    33  29.172880          2259.987459  0.950679
# 12    50  28.850352          2504.038511  0.992868
# 13    50  25.829670          2916.422367  0.750441
# 14    30  27.421882          1743.094823  0.814409
# 15    58  28.437976          2228.651702  0.753506
# 16    27  29.896797          2561.655915  0.879063
# 17    40  27.748392          2071.058626  0.927054
# 18    36  26.735089          2497.934770  0.667829
# 19    35  27.026301          2695.992058  0.826353
# 20    44  28.583371          2440.037148  0.810474
# 21    22  28.310522          1779.041994  0.850563
# 22    25  25.008324          1154.698969  0.770777
# 23    54  28.131215          2245.709174  0.742366
# 24    39  29.452482          2628.232356  0.860640
# 25    19  26.928796          2324.594352  0.957372
# 26    18  27.861642          2429.131681  0.883982
# 27    20  26.608891          2484.036304  0.915456
# 28    59  26.083827          1616.660990  0.887797
# 29    18  26.153516          1657.502887  0.894822
# ..   ...        ...                  ...       ...
# 490   36  37.060813          2430.889534  0.907798
# 491   35  32.584639          2216.587289  0.901783
# 492   61  34.800703          2614.015915  0.746297
# 493   52  39.135326          2528.544887  0.869222
# 494   43  40.629703          2138.675010  0.737104
# 495   57  38.290855          1783.813471  0.883959
# 496   53  32.722621          1736.723051  0.906873
# 497   41  36.493576          2118.669183  0.995103
# 498   57  34.784612          1739.622216  0.881477
# 499   26  32.298850          3232.828660  0.785414
# 500   48  32.262660          2713.413699  0.845395
# 501   59  31.150822          2688.084962  0.863170
# 502   54  41.896998          1741.698381  0.817398
# 503   54  43.705746          2245.847285  0.746725
# 504   53  44.145808          2586.795381  0.856360
# 505   63  30.382132          2702.835189  0.962597
# 506   31  36.894121          2632.976881  0.712037
# 507   55  44.937432          2368.020022  0.874397
# 508   46  32.628426          3208.492459  0.966067
# 509   58  35.337748          1891.213207  0.899991
# 510   28  39.501454          1542.068227  0.926775
# 511   57  37.215259          2484.965879  0.718661
# 512   30  30.663462          2889.132291  0.808608
# 513   35  30.054904          2047.123629  1.004150
# 514   36  36.619347          1636.003330  0.765749
# 515   18  32.843126          2239.066687  0.872868
# 516   42  42.875303          1014.278380  0.987880
# 517   26  32.175467          2494.975144  0.774464
# 518   58  41.610445          2343.902731  0.985151
# 519   24  43.429867          1635.930549  0.924689
#
# [520 rows x 4 columns]

# %%
# Create pairplot of the dataframe

sns.pairplot(df)
plt.show()

# %%
d = sns.PairGrid(df)
d.map(plt.scatter)
plt.show()

# %% [markdown]
# References
# 1. https://www.safefood.eu/SafeFood/media/SafeFoodLibrary/Documents/Professional/Nutrition/Adult-and-children-obesity-trends-ROI.pdf
# 2.   https://irp-cdn.multiscreensite.com/46a7ad27/files/uploaded/The%20National%20Adult%20Nutrition%20Survey%20Summary%20Report%20March%202011.pdf
# 3 https://health.gov/dietaryguidelines/2015/guidelines/appendix-2/
# 4. https://www.nhs.uk/common-health-questions/food-and-diet/what-should-my-daily-intake-of-calories-be/
# 5. https://www.irishexaminer.com/ireland/irish-among-the-biggest-consumers-of-calories-per-day-428077.html
# 6. https://www.cso.ie/en/csolatestnews/pressreleases/2017pressreleases/pressstatementcensus2016resultsprofile3-anageprofileofireland/
# 7. https://en.wikipedia.org/wiki/List_of_average_human_height_worldwide
# 8. https://en.wikipedia.org/wiki/Human_body_weight
# 9. http://www.euro.who.int/en/health-topics/disease-prevention/nutrition/a-healthy-lifestyle/body-mass-index-bmi
# 10. https://epubs.rcsi.ie/cgi/viewcontent.cgi?article=1002&context=psycholrep

# %% [markdown]
# ## End
